# %%
#!rm -rf /kaggle/working/Intelligent-Document-Processing-engine
# !git clone https://github.com/ngahyves/Intelligent-Document-Processing-engine.git
# %cd Intelligent-Document-Processing-engine
# Out:
# Cloning into 'Intelligent-Document-Processing-engine'...
# remote: Enumerating objects: 3225, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 3225 (delta 87), reused 135 (delta 48), pack-reused 3050 (from 1)
# Receiving objects: 100% (3225/3225), 222.80 MiB | 34.03 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# /kaggle/working/Intelligent-Document-Processing-engine

# %%
# !pip install langchain-groq langchain-core langchain --quiet

# %%
# !ls /kaggle/working
# Out:
# Intelligent-Document-Processing-engine

# %%
import sys
sys.path.append('/kaggle/working')
sys.path.append('/kaggle/working/src')

# %%
# !pip install faiss-cpu --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 73.2 MB/s eta 0:00:00:00:0100:01

# %%
from kaggle_secrets import UserSecretsClient
import os

user_secrets = UserSecretsClient()
os.environ["GROQ_API_KEY"] = user_secrets.get_secret("GROQ_API_KEY")

print("Key loaded safely from Kaggle Secrets.")
# Out:
# Key loaded safely from Kaggle Secrets.

# %%
# !python -m src.llm.test_full_rag
# Out:
# 2026-05-19 09:32:29 | __main__ | INFO | ---STARTING FULL RAG TEST ---
# 2026-05-19 09:32:29 | Embedding | INFO | loading embedding model : all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json: 100%|████████████████████████████| 349/349 [00:00<00:00, 1.30MB/s]
# config_sentence_transformers.json: 100%|████████| 116/116 [00:00<00:00, 769kB/s]
# README.md: 10.5kB [00:00, 33.1MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 357kB/s]
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 5.12MB/s]
# model.safetensors: 100%|███████████████████| 90.9M/90.9M [00:00<00:00, 93.7MB/s]
# Loading weights: 100%|█| 103/103 [00:00<00:00, 1537.53it/s, Materializing param=
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100%|███████████████████| 350/350 [00:00<00:00, 2.39MB/s]
# vocab.txt: 232kB [00:00, 13.2MB/s]
# tokenizer.json: 466kB [00:00, 35.8MB/s]
# special_tokens_map.json: 100%|██████████████████| 112/112 [00:00<00:00, 650kB/s]
# config.json: 100%|██████████████████████████████| 190/190 [00:00<00:00, 905kB/s]
# 2026-05-19 09:32:32 | vector Storing | INFO | FAISS Vector Store initialized with dimension: 384
# 2026-05-19 09:32:32 | Embedding | INFO | Generate embeddings for 3 chunks.
# 2026-05-19 09:32:33 | vector Storing | INFO | Successfully added 3 chunks to FAISS index.
# 2026-05-19 09:32:34 | src.llm.rag_chain | INFO | RAG Engine initialized with Llama 3 via Groq.
# 2026-05-19 09:32:34 | src.llm.rag_chain | INFO | Answering question: What is the total price and the address?
# 2026-05-19 09:32:34 | vector Storing | INFO | Performing semantic search for top-3 results.
# 2026-05-19 09:32:34 | src.llm.rag_chain | ERROR | Error in RAG Engine: Error code: 400 - {'error': {'message': 'The model `llama3-8b-8192` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#
# ==============================
# QUESTION: What is the total price and the address?
# LLM ANSWER: I encountered an error processing your request.
# ==============================
