# %%
# !git clone https://github.com/ngahyves/Intelligent-Document-Processing-engine.git
# %cd Intelligent-Document-Processing-engine
# Out:
# Cloning into 'Intelligent-Document-Processing-engine'...
# remote: Enumerating objects: 3245, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 3245 (delta 100), reused 148 (delta 54), pack-reused 3050 (from 1)
# Receiving objects: 100% (3245/3245), 237.00 MiB | 34.82 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# /kaggle/working/Intelligent-Document-Processing-engine

# %% [markdown]
# # 1. Cloning the repository and setting up the environment

# %%
#Install the librairies/dependencies
# !pip install torch torchvision torchaudio dagshub mlflow --quiet
# !pip install mlflow onnx onnxruntime onnxsim scikit-learn python-dotenv fastapi uvicorn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.1/273.1 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 85.6 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.2 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 11.0 MB/s eta 0:00:00
# ...

# %%
#Verify the working directory
# !ls /kaggle/working
# Out:
# Intelligent-Document-Processing-engine

# %%
import sys
sys.path.append('/kaggle/working')
sys.path.append('/kaggle/working/src')

# %% [markdown]
# # 2. Data preprocessing

# %%
# !mkdir -p /kaggle/working/data
# !cp -r /kaggle/input/datasets/ngahyvesbernard/vision-data/data/train /kaggle/working/data/
# !cp -r /kaggle/input/datasets/ngahyvesbernard/vision-data/data/test /kaggle/working/data/

# %%
from src.vision.preprocess import DataProcess

dp = DataProcess(
    train_path="/kaggle/working/data/train",
    test_path="/kaggle/working/data/test"
)

train_loader, test_loader, classes = dp.get_loaders()
print("Classes detected :", classes)
# Out:
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | DataProcess initialized with:
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Train path: /kaggle/working/data/train
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Test path: /kaggle/working/data/test
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Batch size: 32
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Image size: 224
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Num workers: 2
# 2026-05-19 12:40:19 | src.vision.preprocess | WARNING | Datasets not loaded yet. Calling load_datasets()...
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Dataset paths validated successfully.
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Loading datasets...
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Train dataset size: 2500 images
# 2026-05-19 12:40:19 | src.vision.preprocess | INFO | Test dataset size: 500 images
# ...

# %%
# Out:
# 2026-05-19 12:04:13 | __main__ | INFO | Running DataProcess
# 2026-05-19 12:04:13 | __main__ | INFO | DataProcess initialized with:
# 2026-05-19 12:04:13 | __main__ | INFO | Train path: /kaggle/working/Intelligent-Document-Processing-engine/data/train
# 2026-05-19 12:04:13 | __main__ | INFO | Test path: /kaggle/working/Intelligent-Document-Processing-engine/data/test
# 2026-05-19 12:04:13 | __main__ | INFO | Batch size: 32
# 2026-05-19 12:04:13 | __main__ | INFO | Image size: 224
# 2026-05-19 12:04:13 | __main__ | INFO | Num workers: 2
# 2026-05-19 12:04:13 | __main__ | WARNING | Datasets not loaded yet. Calling load_datasets()...
# 2026-05-19 12:04:13 | __main__ | ERROR | Train path not found: /kaggle/working/Intelligent-Document-Processing-engine/data/train
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
# ...

# %% [markdown]
# # 3. Training

# %%
# !mkdir -p /kaggle/working/data

# !cp -r /kaggle/input/datasets/ngahyvesbernard/vision-data/data/train /kaggle/working/data/
# !cp -r /kaggle/input/datasets/ngahyvesbernard/vision-data/data/test /kaggle/working/data/

import os
print(os.listdir("/kaggle/working/data"))
# Out:
# ['test', 'train']

# %%
# 1. On modifie les variables d'environnement pour override les paths
import os
os.environ["TRAIN_DIR"] = "/kaggle/working/data/train"
os.environ["TEST_DIR"] = "/kaggle/working/data/test"

# 2. On exécute ton script train.py normalement
# !python /kaggle/working/Intelligent-Document-Processing-engine/src/vision/train.py
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/Intelligent-Document-Processing-engine/src/vision/train.py", line 11, in <module>
#     from src.vision.preprocess import DataProcess
# ModuleNotFoundError: No module named 'src'

# %%
# %cd /kaggle/working/Intelligent-Document-Processing-engine
# Out:
# /kaggle/working/Intelligent-Document-Processing-engine

# %%
import os
os.environ["TRAIN_DIR"] = "/kaggle/working/data/train"
os.environ["TEST_DIR"] = "/kaggle/working/data/test"

# %%
# !python -m src.vision.train
# Out:
# Accessing as ngahyves
# Initialized MLflow to track repo "ngahyves/idp-engine"
# Repository ngahyves/idp-engine initialized!
# INFO:__main__:Starting training script...
# INFO:__main__:Random seed set to 42
# 2026-05-19 12:46:52 | src.vision.preprocess | INFO | DataProcess initialized with:
# INFO:src.vision.preprocess:DataProcess initialized with:
# 2026-05-19 12:46:52 | src.vision.preprocess | INFO | Train path: /kaggle/working/data/train
# INFO:src.vision.preprocess:Train path: /kaggle/working/data/train
# 2026-05-19 12:46:52 | src.vision.preprocess | INFO | Test path: /kaggle/working/data/test
# INFO:src.vision.preprocess:Test path: /kaggle/working/data/test
# 2026-05-19 12:46:52 | src.vision.preprocess | INFO | Batch size: 32
# INFO:src.vision.preprocess:Batch size: 32
# 2026-05-19 12:46:52 | src.vision.preprocess | INFO | Image size: 224
# INFO:src.vision.preprocess:Image size: 224
# 2026-05-19 12:46:52 | src.vision.preprocess | INFO | Num workers: 2
# ...

# %%
#Export the model to onnx run time format
# !pip install onnx onnxscript
# !python -m src.vision.export_onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.8/714.8 kB 11.1 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.8/166.8 kB 14.4 MB/s eta 0:00:00
# ...
# Accessing as ngahyves
# Initialized MLflow to track repo "ngahyves/idp-engine"
# Repository ngahyves/idp-engine initialized!
# Detected num_classes = 5
# INFO:src.vision.train:Loading EfficientNet-B0 pretrained model...
# INFO:src.vision.train:Model head replaced for 5 classes.
# /kaggle/working/Intelligent-Document-Processing-engine/src/vision/export_onnx.py:12: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# ...
